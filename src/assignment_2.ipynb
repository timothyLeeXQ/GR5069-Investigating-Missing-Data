# %% [markdown]
# # Assignment 2: Analysing missing data in F1 Dataset
#
# **Objectives:**
#
# * Uncover patterns of missing data in datasets
# * See how missing data can affect the distribution of variables
# * Use and evaluate imputation techniques

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Load Relevant Packages

# %%
from pyspark.sql.types import IntegerType
from pyspark.sql import functions as F
import pandas as pd
import numpy as np
from numpy.random import rand
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Mount S3 Bucket to obtain data
#
# * Provide AWS Access Keys for authentication
# * **DELETE ACCESS KEYS IMMEDIATELY AFTER MOUNTING**
# * Provide AWS Bucket Name and mount name
# * Expect successful mount - line 8 should produce paths to be used to get data

# %%
# Uncomment, insert credentials, and run to mount
#ACCESS_KEY = ''
# Encode the Secret Key as that can contain '/'
#SECRET_KEY = ''.replace("/", "%2F")
#AWS_BUCKET_NAME_RAW = 'ne-gr5069'
#MOUNT_NAME_RAW = 'ne-gr5069'

#dbutils.fs.mount('s3a://%s:%s@%s' % (ACCESS_KEY, SECRET_KEY, AWS_BUCKET_NAME_RAW),
#                 '/mnt/%s' % MOUNT_NAME_RAW)
#display(dbutils.fs.ls('/mnt/%s' % MOUNT_NAME_RAW))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Mount S3 Bucket to Write Data

# %%
AWS_BUCKET_NAME_PROC = 'xql2001-gr5069'
MOUNT_NAME_PROC = 'xql2001-gr5069'

dbutils.fs.mount('s3a://%s:%s@%s' % (ACCESS_KEY, SECRET_KEY, AWS_BUCKET_NAME_PROC),
                 '/mnt/%s' % MOUNT_NAME_PROC)
display(dbutils.fs.ls('/mnt/%s' % MOUNT_NAME_PROC))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/mnt/xql2001-gr5069/interim/</td><td>interim/</td><td>0</td></tr><tr><td>dbfs:/mnt/xql2001-gr5069/processed/</td><td>processed/</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# ### Define functions to be used throughout

# %%
def fill_dummy_values(df, scaling_factor):
  # Since Matplotlib does not plot missing values, we would have to create 
  # a function that fills dummy variables into the null values of the
  # dataframe
    #create copy of dataframe
    df_dummy = df.copy(deep = True)
    # Iterate over each column
    for col in df_dummy:
        if df_dummy.dtypes[col] != np.object:
          #get column, column missing values and range
          col = df_dummy[col]
          col_null = col.isnull()
          num_nulls = col_null.sum()
          col_range = col.max() - col.min()
        
          #Shift and scale dummy values
          dummy_values = (rand(num_nulls) - 2)
          dummy_values = dummy_values * scaling_factor * col_range + col.min()
        
          #Return dummy values
          col[col_null] = dummy_values
    return df_dummy

def cols_to_int_type(df, col_list):
  # :::::::::::: DESCRIPTION
  # This function is used to change a set of columns in a dataframe to an
  # integer type by looping through through columnsprovided as a list
  #
  # Functionalising this because many of the dfs in the F1 data should be
  # integers, but every variable is imported as string
  #
  # ::::::::: INPUTS
  # 1. df - the dataframe with columns to be changed to int. Should be a 
  #    pyspark.sql dataframe object
  # 2. col_list - a list of strings - each the name of a column in the df
  #    that is to be changed to an integer datatype
  #
  # ::::::::: OUTPUT
  # The dataframe entered as an argument, but with the desired columns
  # cast to the datatype Integer
  #
  for colname in col_list:
    df = df.withColumn(colname, df[colname].cast(IntegerType()))
  return(df)


def encode(data):
    '''function to encode non-null data and replace it in the original data'''
    #retains only non-null values
    nonulls = np.array(data.dropna())
    #reshapes the data for encoding
    impute_reshape = nonulls.reshape(-1,1)
    #encode date
    impute_ordinal = encoder.fit_transform(impute_reshape)
    #Assign back encoded values to non-null values
    data.loc[data.notnull()] = np.squeeze(impute_ordinal)
    return data
  
def RMSE(predict, target):
  #Calculate RMSE
  return np.sqrt(((predict - target) ** 2).mean())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### Load in missing data dataset

# %%
df_missing = spark.read.csv('/mnt/ne-gr5069/raw/df_missing.csv', header = True)
display(df_missing)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>17</td><td>2</td><td>1:37.663</td><td>97663</td></tr><tr><td>2</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>18</td><td>2</td><td>1:37.579</td><td>97579</td></tr><tr><td>3</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>19</td><td>1</td><td>1:37.720</td><td>97720</td></tr><tr><td>4</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>20</td><td>1</td><td>1:40.973</td><td>100973</td></tr><tr><td>5</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>21</td><td>3</td><td>2:00.933</td><td>120933</td></tr><tr><td>6</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>22</td><td>3</td><td>1:36.701</td><td>96701</td></tr><tr><td>7</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>23</td><td>2</td><td>1:37.257</td><td>97257</td></tr><tr><td>8</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>24</td><td>2</td><td>1:37.907</td><td>97907</td></tr><tr><td>9</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>25</td><td>2</td><td>1:38.180</td><td>98180</td></tr><tr><td>10</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>26</td><td>2</td><td>1:37.822</td><td>97822</td></tr><tr><td>11</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>27</td><td>2</td><td>1:37.816</td><td>97816</td></tr><tr><td>12</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>28</td><td>2</td><td>1:37.673</td><td>97673</td></tr><tr><td>13</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>29</td><td>2</td><td>1:37.892</td><td>97892</td></tr><tr><td>14</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>30</td><td>2</td><td ...

# %%
display(df_missing.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td></tr><tr><td>mean</td><td>236252.5</td><td>229.7737775764861</td><td>null</td><td>25.328412820757087</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>36.98124702198625</td><td>480.07822156002914</td><td>29.871804259858116</td><td>9.651368030746829</td><td>null</td><td>94899.58912224017</td></tr><tr><td>stddev</td><td>136400.3001340784</td><td>345.3821632369074</td><td>null</td><td>24.985651553593236</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7.251128022983076</td><td>402.0313510566064</td><td>18.38969559962932</td><td>5.562433907092902</td><td>null</td><td>66244.43117416694</td></tr><tr><td>min</td><td>1</td><td>1</td><td>albers</td><td>10</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>American</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td><td>1</td><td>1</td><td>1</td><td>15:25.994</td><td>100000</td></tr><tr><td>25%</td><td>118129.0</td><td>14.0</td><td>null</td><td>8.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>32.0</td><td>112.0</td><td>14.0</td><td>5.0</td><td>null</td><td>81931.0</td></tr><tr><td>50%</td><td>236205.0</td><td>30.0</td><td>null</td><td>19.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>38.0</td><td>228.0</td><td>29.0</td><td>9.0</td><td>null</td><td>90364.0</td></tr><tr><td>75%</td><td>354341.0</td><td>807.0</td><td>null</td><td>28.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>43.0</td><td>911.0</td><td>44.0</td><td>14.0</td><td>null</td><td>102028.0</td></tr><tr><td>max</td><td>99999</td><td>9</td><td>zonta</td><td>\N</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>Venezuelan</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>NA</td><td>999</td><td>9</td><td>9</td><td>NA</td><td>NA</td></tr></tbody></table></div>

# %% [markdown]
# ### Change datatype of appropriate columns to int

# %%
df_missing_int_colname = ['_c0',
                          'driverId',
                          'number',
                          'age',
                          'raceId',
                          'lap',
                          'position',
                          'milliseconds']

df_missing = cols_to_int_type(df_missing, df_missing_int_colname)
display(df_missing)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>1</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>17</td><td>2</td><td>1:37.663</td><td>97663</td></tr><tr><td>2</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>18</td><td>2</td><td>1:37.579</td><td>97579</td></tr><tr><td>3</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>19</td><td>1</td><td>1:37.720</td><td>97720</td></tr><tr><td>4</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>20</td><td>1</td><td>1:40.973</td><td>100973</td></tr><tr><td>5</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>21</td><td>3</td><td>2:00.933</td><td>120933</td></tr><tr><td>6</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>22</td><td>3</td><td>1:36.701</td><td>96701</td></tr><tr><td>7</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>23</td><td>2</td><td>1:37.257</td><td>97257</td></tr><tr><td>8</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>24</td><td>2</td><td>1:37.907</td><td>97907</td></tr><tr><td>9</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>25</td><td>2</td><td>1:38.180</td><td>98180</td></tr><tr><td>10</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>26</td><td>2</td><td>1:37.822</td><td>97822</td></tr><tr><td>11</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>27</td><td>2</td><td>1:37.816</td><td>97816</td></tr><tr><td>12</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>28</td><td>2</td><td>1:37.673</td><td>97673</td></tr><tr><td>13</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>29</td><td>2</td><td>1:37.892</td><td>97892</td></tr><tr><td>14</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>30</td><td>2</td><td ...

# %% [markdown]
# ### Identify and Isolate Missing values
#
# *There are missing values in other rows as well, like driver code (in the last
# assignment), but here our focus is on the 3 identified for the assignment -
# `milliseconds`, `nationality`, and `age`*
#
# I downloaded the raw data and the datatype transformed data from above and had
# a look in Excel (shameless, I know, but it's just very comfortable to use
# Excel when one needs to just scroll through a table and have a look).
#
# Missing values in the raw data were coded as "NA". This is still true for the
# 'nationality' column, which is still string type. For the age and milliseconds
# columns, transforming the data to integer type caused non number values to
# become blank (e.g. from NA to a blank).
#
# The following cells are meant to further explore the data after transformation.
# The main goal is to see if we've managed to identify the pattern of all the
# missing or invalid values (all missing values are coded NA, not NULL or
# NaN, and no more stray missing or invalid vals in age and milliseconds)

# %%
display(df_missing.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>472504</td><td>472504</td><td>472504</td><td>230938</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>411348</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>425253</td></tr><tr><td>mean</td><td>236252.5</td><td>229.7737775764861</td><td>null</td><td>25.328412820757087</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>36.98124702198625</td><td>480.07822156002914</td><td>29.871804259858116</td><td>9.651368030746829</td><td>null</td><td>94899.58912224017</td></tr><tr><td>stddev</td><td>136400.3001340784</td><td>345.3821632369074</td><td>null</td><td>24.985651553593236</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7.251128022983076</td><td>402.0313510566064</td><td>18.38969559962932</td><td>5.562433907092902</td><td>null</td><td>66244.43117416694</td></tr><tr><td>min</td><td>1</td><td>1</td><td>albers</td><td>2</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>American</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td><td>1</td><td>1</td><td>1</td><td>15:25.994</td><td>66957</td></tr><tr><td>25%</td><td>118129</td><td>14</td><td>null</td><td>8</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>32</td><td>112</td><td>14</td><td>5</td><td>null</td><td>81931</td></tr><tr><td>50%</td><td>236205</td><td>30</td><td>null</td><td>19</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>38</td><td>228</td><td>29</td><td>9</td><td>null</td><td>90364</td></tr><tr><td>75%</td><td>354341</td><td>807</td><td>null</td><td>28</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>43</td><td>911</td><td>44</td><td>14</td><td>null</td><td>102028</td></tr><tr><td>max</td><td>472504</td><td>848</td><td>zonta</td><td>99</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>Venezuelan</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>48</td><td>1030</td><td>78</td><td>24</td><td>NA</td><td>7507547</td></tr></tbody></table></div>

# %%
df_missing_unique_nationality = df_missing.groupby('nationality')\
  .count()

display(df_missing_unique_nationality)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>nationality</th><th>count</th></tr></thead><tbody><tr><td>Mexican</td><td>11498</td></tr><tr><td>Finnish</td><td>35924</td></tr><tr><td>Swiss</td><td>2334</td></tr><tr><td>Thai</td><td>1117</td></tr><tr><td>NA</td><td>47112</td></tr><tr><td>Indian</td><td>2502</td></tr><tr><td>Indonesian</td><td>554</td></tr><tr><td>Irish</td><td>570</td></tr><tr><td>Argentine</td><td>1659</td></tr><tr><td>Polish</td><td>4858</td></tr><tr><td>British</td><td>60361</td></tr><tr><td>Japanese</td><td>13463</td></tr><tr><td>Australian</td><td>18355</td></tr><tr><td>Spanish</td><td>28319</td></tr><tr><td>Portuguese</td><td>2387</td></tr><tr><td>Hungarian</td><td>851</td></tr><tr><td>Austrian</td><td>7082</td></tr><tr><td>New Zealander</td><td>1060</td></tr><tr><td>Italian</td><td>29523</td></tr><tr><td>Danish</td><td>5976</td></tr><tr><td>Russian</td><td>8043</td></tr><tr><td>French</td><td>29105</td></tr><tr><td>Malaysian</td><td>589</td></tr><tr><td>Colombian</td><td>4420</td></tr><tr><td>Dutch</td><td>11646</td></tr><tr><td>Brazilian</td><td>41925</td></tr><tr><td>Monegasque</td><td>1987</td></tr><tr><td>German</td><td>75715</td></tr><tr><td>Venezuelan</td><td>4075</td></tr><tr><td>Swedish</td><td>4421</td></tr><tr><td>American</td><td>1441</td></tr><tr><td>Czech</td><td>148</td></tr><tr><td>Belgian</td><td>2935</td></tr><tr><td>Canadian</td><td>10549</td></tr></tbody></table></div>

# %% [markdown]
# **Age and millisecond data:**
# It seems that the change to integer type has led to some missing data being
# identified. summary() now produces 411348 entries for age and 425253 entries
# for milliseconds, both less than the total number of rows, 472504.
#
# The average, min, and max values of age and milliseconds appear to be
# reasonable for F1 drivers and laps. I think it is reasonable to conclude any
# data left in the column are valid ages and laptimes.
#
# **Nationality data:**
#
# It appears the only values that NA is the only tag for missing values.
# Everything else seems to be a valid nationality.
#
# Although, the overall DF summary suggests that there was no missing data in the
# nationality set, that's likely because "NA" was considered a valid string.
#
# The groupby operation above shows that there were 47112 NA values, which should
# be all missing values in the column. This corresponds to 425392 valid entries.

# %% [markdown]
# ## 1. Three variables, `milliseconds`, `nationality` and `age` have different missingness patterns. Use exploratory data analysis to determine the missingness pattern on each variable, and explain how you reached that conclusion.

# %% [markdown]
# ### Age
# Will first try to filter for just the missing data and look for patterns

# %%
df_age_na = df_missing.where(F.col('age').isNull())
display(df_age_na)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>226223</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>81</td><td>18</td><td>6</td><td>1:23.263</td><td>83263</td></tr><tr><td>226224</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>96</td><td>27</td><td>1</td><td>1:30.867</td><td>90867</td></tr><tr><td>226225</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>96</td><td>16</td><td>1</td><td>1:31.407</td><td>91407</td></tr><tr><td>226226</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>340</td><td>55</td><td>10</td><td>1:56.373</td><td>116373</td></tr><tr><td>226227</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>173</td><td>34</td><td>2</td><td>1:41.073</td><td>101073</td></tr><tr><td>226228</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>96</td><td>11</td><td>3</td><td>1:31.545</td><td>91545</td></tr><tr><td>226229</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>129</td><td>13</td><td>2</td><td>1:10.454</td><td>70454</td></tr><tr><td>226230</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>129</td><td>14</td><td>2</td><td>1:09.914</td><td>69914</td></tr><tr><td>226231</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>340</td><td>38</td><td>11</td><td>1:49.066</td><td>109066</td></tr><tr><td>226232</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>134</td><td>52</td><td>3</td><td>1:15.779</td><td>75779</td></tr><tr><td>226233</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>NA</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>129</td><td>11</td><td>2</td><td>1:10.380</td><td>70380</td></tr><tr><td>226234</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http://en.wikipedia.org/wiki/Michael_Schumacher</td><td>null</td><td>70</td><td>6</td><td>6</td><td>1:53.176</td><td>113176</td></tr><tr><td>226235</td><td>30</td><td>michael_schumacher</td><td>null</td><td>MSC</td><td>Michael</td><td>Schumacher</td><td>1969-01-03</td><td>German</td><td>http ...

# %%
# Check if this is all the missing values
display(df_age_na.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>61156</td><td>61156</td><td>61156</td><td>0</td><td>61156</td><td>61156</td><td>61156</td><td>61156</td><td>61156</td><td>61156</td><td>0</td><td>61156</td><td>61156</td><td>61156</td><td>61156</td><td>58583</td></tr><tr><td>mean</td><td>288821.4984956505</td><td>53.00956570083066</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>204.3344888481915</td><td>29.856596245666818</td><td>8.046585780626595</td><td>null</td><td>91961.53795469676</td></tr><tr><td>stddev</td><td>34336.11243575735</td><td>15.058211199776613</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>126.41691291549411</td><td>18.933034311167777</td><td>5.066620639823924</td><td>null</td><td>38600.2245319102</td></tr><tr><td>min</td><td>226223</td><td>30</td><td>alesi</td><td>null</td><td>MSC</td><td>Alessandro</td><td>Alesi</td><td>1958-02-18</td><td>Austrian</td><td>http://en.wikipedia.org/wiki/Alex_Zanardi</td><td>null</td><td>53</td><td>1</td><td>1</td><td>19:29.677</td><td>68337</td></tr><tr><td>25%</td><td>271246</td><td>44</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>156</td><td>14</td><td>4</td><td>null</td><td>82126</td></tr><tr><td>50%</td><td>296776</td><td>56</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>192</td><td>28</td><td>8</td><td>null</td><td>87361</td></tr><tr><td>75%</td><td>315801</td><td>64</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>220</td><td>44</td><td>12</td><td>null</td><td>97727</td></tr><tr><td>max</td><td>339823</td><td>86</td><td>zanardi</td><td>null</td><td>\N</td><td>Ukyo</td><td>Zanardi</td><td>1970-05-22</td><td>NA</td><td>http://en.wikipedia.org/wiki/Ukyo_Katayama</td><td>null</td><td>879</td><td>78</td><td>24</td><td>NA</td><td>7502081</td></tr></tbody></table></div>

# %%
# Looks like we're good
61156 + 411348
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: 472504</div>

# %% [markdown]
# By clicking the sort buttons in the filtered data table and looking at the
# summary, I think the missingness pattern is related to the drivers, for
# the following reasons:
#
# 1. Other variables appear to have the full range of variation. Only raceId and
# driver related variables like driverId appear to have truncated variation. The
# filtered dataset only contains race numbers 50-879 as opposed to 1-1030, and
# drivers 30-86 as opposed to 1-848.
#
# 2. Sorting the table with only missing age values up and down in databricks
# does not do anything for driver related variables. Only Michael Schumacher
# is reflected.
#
# I think the restriction in the range of raceIds might be related to the
# drivers. As drivers 30-86 probably don't have careers that span the whole
# dataset, they aren't going to have all the raceIds reflected in their data.
# Furthermore, looking at the data in Excel (again!) I realised that all Michael
# Schumacher's age data is missing, not just those for specific races. So I'm
# going to look into driverIds first and see if that resolves the issue, then
# look at races if it does not.

# %%
df_age_na_driverIds = df_age_na.groupby('driverId')\
  .count()
display(df_age_na_driverIds)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>driverId</th><th>count</th></tr></thead><tbody><tr><td>85</td><td>119</td></tr><tr><td>65</td><td>3740</td></tr><tr><td>78</td><td>277</td></tr><tr><td>81</td><td>355</td></tr><tr><td>44</td><td>5891</td></tr><tr><td>86</td><td>139</td></tr><tr><td>57</td><td>4957</td></tr><tr><td>64</td><td>3082</td></tr><tr><td>55</td><td>4870</td></tr><tr><td>49</td><td>5831</td></tr><tr><td>84</td><td>705</td></tr><tr><td>63</td><td>4388</td></tr><tr><td>77</td><td>1582</td></tr><tr><td>73</td><td>1076</td></tr><tr><td>70</td><td>585</td></tr><tr><td>56</td><td>5523</td></tr><tr><td>71</td><td>2977</td></tr><tr><td>79</td><td>1252</td></tr><tr><td>30</td><td>13168</td></tr><tr><td>66</td><td>639</td></tr></tbody></table></div>

# %%
list_age_na_drivers = df_age_na_driverIds.toPandas()['driverId'].tolist()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_age_na_replicated = df_missing\
  .where(F.col('driverId').isin(list_age_na_drivers))

display(df_age_na_replicated.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>61156</td><td>61156</td><td>61156</td><td>0</td><td>61156</td><td>61156</td><td>61156</td><td>61156</td><td>61156</td><td>61156</td><td>0</td><td>61156</td><td>61156</td><td>61156</td><td>61156</td><td>58583</td></tr><tr><td>mean</td><td>288821.4984956505</td><td>53.00956570083066</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>204.3344888481915</td><td>29.856596245666818</td><td>8.046585780626595</td><td>null</td><td>91961.53795469676</td></tr><tr><td>stddev</td><td>34336.11243575735</td><td>15.058211199776613</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>126.41691291549411</td><td>18.933034311167777</td><td>5.066620639823924</td><td>null</td><td>38600.2245319102</td></tr><tr><td>min</td><td>226223</td><td>30</td><td>alesi</td><td>null</td><td>MSC</td><td>Alessandro</td><td>Alesi</td><td>1958-02-18</td><td>Austrian</td><td>http://en.wikipedia.org/wiki/Alex_Zanardi</td><td>null</td><td>53</td><td>1</td><td>1</td><td>19:29.677</td><td>68337</td></tr><tr><td>25%</td><td>271246</td><td>44</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>156</td><td>14</td><td>4</td><td>null</td><td>82126</td></tr><tr><td>50%</td><td>296776</td><td>56</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>192</td><td>28</td><td>8</td><td>null</td><td>87361</td></tr><tr><td>75%</td><td>315801</td><td>64</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>220</td><td>44</td><td>12</td><td>null</td><td>97727</td></tr><tr><td>max</td><td>339823</td><td>86</td><td>zanardi</td><td>null</td><td>\N</td><td>Ukyo</td><td>Zanardi</td><td>1970-05-22</td><td>NA</td><td>http://en.wikipedia.org/wiki/Ukyo_Katayama</td><td>null</td><td>879</td><td>78</td><td>24</td><td>NA</td><td>7502081</td></tr></tbody></table></div>

# %% [markdown]
# Success! By getting the driverIds within df_age_na dataframe, then
# filtering the overall missing dataset to include entries with only these
# driverIds, we successfully replicated the df_age_na dataframe in the
# dataframe df_age_na_replicated, as can be seen by:
#
# 1. Counts are the same for both these dataframes
# 2. Age is missing for the entire replicated dataframe.
# 3. Descriptive stats for variables like lap, position, and milliseconds
#  are identical.
#
#  We can thus conclude that the missingness pattern of age in df_missing
#  is that age is missing for the drivers with driverIds contained within
#  `list_age_na_drivers`.
#
#  **Note:** With hindsight having done questions 2 and 3, it is also
#  clear that the drivers with missing age data were all over 50 years
#  old. Given that the df_missing dataset simply didn't have this data,
#  it was impossible to know this without looking at the original data
#  first. This leaves 2 possibilities:
#  1. All ages above 50 were removed, creating a situation where all
#  the ages of drivers in `list_age_na_drivers` were removed, without
#  affecting any other driverrs (since they were below 50 years old).
#  2. The ages of drivers in `list_age_na_drivers` were intentionally
#  removed, and they were all above 50 years old.
#
#  1 is the more likely scenario, but without looking at the original
#  data until tackling question 2, I was led to believe that 2 was
#  what was happening.

# %% [markdown]
# ### Milliseconds
#
# Will try the same strategy as was done for age. After all it worked once.

# %%
df_milliseconds_na = df_missing.where(F.col('milliseconds').isNull())
display(df_milliseconds_na)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>1129</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>1</td><td>21</td><td>NA</td><td>null</td></tr><tr><td>1130</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>2</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1131</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>3</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1132</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>4</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1133</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>5</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1134</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>6</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1135</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>7</td><td>21</td><td>NA</td><td>null</td></tr><tr><td>1136</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>8</td><td>21</td><td>NA</td><td>null</td></tr><tr><td>1137</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>9</td><td>19</td><td>NA</td><td>null</td></tr><tr><td>2886</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>910</td><td>1</td><td>21</td><td>NA</td><td>null</td></tr><tr><td>2887</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>910</td><td>2</td><td>21</td><td>NA</td><td>null</td></tr><tr><td>2888</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>910</td><td>3</td><td>19</td><td>NA</td><td>null</td></tr><tr><td>3082</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>6</td><td>1</td><td>18</td><td>NA</td><td>null</td></tr><tr><td>3091</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>6</td><td>10</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>3092</ ...

# %%
display(df_milliseconds_na.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>47251</td><td>47251</td><td>47251</td><td>18531</td><td>47251</td><td>47251</td><td>47251</td><td>47251</td><td>47251</td><td>47251</td><td>44678</td><td>47251</td><td>47251</td><td>47251</td><td>47251</td><td>0</td></tr><tr><td>mean</td><td>282873.4741910224</td><td>337.3749127002603</td><td>null</td><td>33.68501430036156</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>35.96982855096468</td><td>574.0513005015766</td><td>22.42278470296925</td><td>19.252883536856363</td><td>null</td><td>null</td></tr><tr><td>stddev</td><td>130533.78086568201</td><td>384.0752704949198</td><td>null</td><td>33.094338024920155</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7.035442027441691</td><td>386.28413178479366</td><td>16.18108571840029</td><td>1.5193377464160913</td><td>null</td><td>null</td></tr><tr><td>min</td><td>1129</td><td>1</td><td>albers</td><td>2</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>American</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td><td>1</td><td>1</td><td>16</td><td>NA</td><td>null</td></tr><tr><td>25%</td><td>173531</td><td>20</td><td>null</td><td>9</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>30</td><td>160</td><td>9</td><td>18</td><td>null</td><td>null</td></tr><tr><td>50%</td><td>306739</td><td>58</td><td>null</td><td>19</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>37</td><td>849</td><td>19</td><td>19</td><td>null</td><td>null</td></tr><tr><td>75%</td><td>401539</td><td>819</td><td>null</td><td>53</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>42</td><td>902</td><td>34</td><td>20</td><td>null</td><td>null</td></tr><tr><td>max</td><td>472421</td><td>848</td><td>zonta</td><td>99</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>Venezuelan</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>48</td><td>1030</td><td>77</td><td>24</td><td>NA</td><td>null</td></tr></tbody></table></div>

# %%
# Looks good here too
47251 + 425253
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[16]: 472504</div>

# %% [markdown]
# Missingness here appears to be related to position. The full df_missing
# dataset has positions from 1-24, whereas this dataset, containing only data
# where milliseconds is missing only has positions from 16 to 24.
#
# Other variables appear similar or the same as the full df_missing dataset,
# so will look at position first.

# %%
df_milliseconds_na_pos_16_filter = df_missing\
  .filter(F.col('position') >= 16)
display(df_milliseconds_na_pos_16_filter)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>1129</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>1</td><td>21</td><td>NA</td><td>null</td></tr><tr><td>1130</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>2</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1131</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>3</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1132</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>4</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1133</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>5</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1134</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>6</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>1135</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>7</td><td>21</td><td>NA</td><td>null</td></tr><tr><td>1136</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>8</td><td>21</td><td>NA</td><td>null</td></tr><tr><td>1137</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>9</td><td>19</td><td>NA</td><td>null</td></tr><tr><td>1138</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>10</td><td>16</td><td>1:44.596</td><td>104596</td></tr><tr><td>2211</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>43</td><td>16</td><td>1:34.025</td><td>94025</td></tr><tr><td>2212</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>44</td><td>16</td><td>1:43.429</td><td>103429</td></tr><tr><td>2213</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>45</td><td>16</td><td>1:23.280</td><td>83280</td></tr><tr><td>2214</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>46</td><td>16</td><td>1:23.307</td><td>83 ...

# %%
display(df_milliseconds_na_pos_16_filter.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>84943</td><td>84943</td><td>84943</td><td>35524</td><td>84943</td><td>84943</td><td>84943</td><td>84943</td><td>84943</td><td>84943</td><td>79637</td><td>84943</td><td>84943</td><td>84943</td><td>84943</td><td>37692</td></tr><tr><td>mean</td><td>282268.90936274914</td><td>330.38702423978435</td><td>null</td><td>32.40001125999324</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>35.90548363198011</td><td>548.8676053353425</td><td>24.364044123706485</td><td>18.031774248613775</td><td>null</td><td>97800.82261487849</td></tr><tr><td>stddev</td><td>131967.98303180822</td><td>381.91330128278076</td><td>null</td><td>31.881218084450705</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7.224395670468197</td><td>397.1515565492083</td><td>16.749126260242214</td><td>1.8193315495327496</td><td>null</td><td>77262.47096534725</td></tr><tr><td>min</td><td>1129</td><td>1</td><td>albers</td><td>2</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>American</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td><td>1</td><td>1</td><td>16</td><td>16:16.243</td><td>68061</td></tr><tr><td>25%</td><td>172764</td><td>20</td><td>null</td><td>9</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>29</td><td>135</td><td>10</td><td>17</td><td>null</td><td>83911</td></tr><tr><td>50%</td><td>307021</td><td>58</td><td>null</td><td>20</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>37</td><td>845</td><td>22</td><td>18</td><td>null</td><td>93172</td></tr><tr><td>75%</td><td>401419</td><td>819</td><td>null</td><td>35</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>42</td><td>910</td><td>37</td><td>19</td><td>null</td><td>104547</td></tr><tr><td>max</td><td>472423</td><td>848</td><td>zonta</td><td>99</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>Venezuelan</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>48</td><td>1030</td><td>77</td><td>24</td><td>NA</td><td>7496893</td></tr></tbody></table></div>

# %% [markdown]
# Unfortunately that didn't work out. The dataset df_milliseconds_na_pos_filter
# filtered for positions equal to or more than 16, but this produced a
# dataframe almost twice the size of our milliseconds missing dataset, with
# some milliseconds values not missing.
#
# To see the difference between the missing and non missing milliseconds values,
# I've filtered the dataset further to provide us with a dataframe with positions
# equal to or more than 16, and only non-missing milliseconds values

# %%
df_milliseconds_filled_pos_filter = df_milliseconds_na_pos_16_filter\
  .where(F.col('milliseconds').isNotNull())

display(df_milliseconds_filled_pos_filter)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>1138</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>950</td><td>10</td><td>16</td><td>1:44.596</td><td>104596</td></tr><tr><td>2211</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>43</td><td>16</td><td>1:34.025</td><td>94025</td></tr><tr><td>2212</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>44</td><td>16</td><td>1:43.429</td><td>103429</td></tr><tr><td>2213</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>45</td><td>16</td><td>1:23.280</td><td>83280</td></tr><tr><td>2214</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>46</td><td>16</td><td>1:23.307</td><td>83307</td></tr><tr><td>2215</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>47</td><td>16</td><td>1:23.417</td><td>83417</td></tr><tr><td>2216</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>48</td><td>16</td><td>1:23.470</td><td>83470</td></tr><tr><td>2217</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>49</td><td>16</td><td>1:25.365</td><td>85365</td></tr><tr><td>2218</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>50</td><td>16</td><td>1:24.629</td><td>84629</td></tr><tr><td>2219</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>51</td><td>16</td><td>1:27.392</td><td>87392</td></tr><tr><td>2220</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>52</td><td>16</td><td>1:25.360</td><td>85360</td></tr><tr><td>2221</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>53</td><td>16</td><td>1:24.555</td><td>84555</td></tr><tr><td>2222</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>8</td><td>54</td><td>16</td><td>1:23.363</td><td>83363</td></tr><tr><td>2223</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td>< ...

# %%
display(df_milliseconds_filled_pos_filter.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>37692</td><td>37692</td><td>37692</td><td>16993</td><td>37692</td><td>37692</td><td>37692</td><td>37692</td><td>37692</td><td>37692</td><td>34959</td><td>37692</td><td>37692</td><td>37692</td><td>37692</td><td>37692</td></tr><tr><td>mean</td><td>281511.0219409954</td><td>321.6269500159185</td><td>null</td><td>30.99870534926146</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>35.82325009296605</td><td>517.2971187519898</td><td>26.79762283773745</td><td>16.500981640666453</td><td>null</td><td>97800.82261487849</td></tr><tr><td>stddev</td><td>133742.06402474834</td><td>379.00876169393905</td><td>null</td><td>30.44256305268062</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7.458209489556054</td><td>408.1849172640876</td><td>17.12727698627041</td><td>0.5940942822638541</td><td>null</td><td>77262.47096534725</td></tr><tr><td>min</td><td>1138</td><td>1</td><td>albers</td><td>2</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>American</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td><td>1</td><td>1</td><td>16</td><td>16:16.243</td><td>68061</td></tr><tr><td>25%</td><td>172245</td><td>20</td><td>null</td><td>10</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>29</td><td>111</td><td>12</td><td>16</td><td>null</td><td>83911</td></tr><tr><td>50%</td><td>307699</td><td>59</td><td>null</td><td>20</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>37</td><td>348</td><td>25</td><td>16</td><td>null</td><td>93172</td></tr><tr><td>75%</td><td>401064</td><td>819</td><td>null</td><td>33</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>42</td><td>931</td><td>40</td><td>17</td><td>null</td><td>104547</td></tr><tr><td>max</td><td>472423</td><td>848</td><td>zonta</td><td>99</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>Venezuelan</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>48</td><td>1030</td><td>77</td><td>19</td><td>9:45.712</td><td>7496893</td></tr></tbody></table></div>

# %% [markdown]
# Comparing our milliseconds missing data to the non-missing milliseconds data
# to the data with both, though all with positions >= 16, we see a further
# difference in the positions data.
#
# 1. The means of the positions data is smaller in the dataset where all
# milliseconds information is missing than in the combined dataset, which is
# smaller than in the dataset containing only non-missing milliseconds data
# where positions >= 16.
#
# 2. Range for non-missing milliseconds data positions is 16-19, not 16-24.
# Meaning all positions >=20 are NA. Testing this theory below.

# %%
df_milliseconds_na_pos_20_filter = df_milliseconds_na_pos_16_filter\
  .filter(F.col('position') >= 20)
display(df_milliseconds_na_pos_20_filter.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>17489</td><td>17489</td><td>17489</td><td>5745</td><td>17489</td><td>17489</td><td>17489</td><td>17489</td><td>17489</td><td>17489</td><td>16738</td><td>17489</td><td>17489</td><td>17489</td><td>17489</td><td>0</td></tr><tr><td>mean</td><td>284823.2458688318</td><td>340.5766481788553</td><td>null</td><td>31.166579634464753</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>36.53566734376867</td><td>618.3144833895592</td><td>19.70764480530619</td><td>20.89524844187775</td><td>null</td><td>null</td></tr><tr><td>stddev</td><td>121692.02781287374</td><td>384.1266267921892</td><td>null</td><td>33.80638172828929</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>6.760152352666198</td><td>353.79072303510793</td><td>15.192705030137015</td><td>1.0825408704222177</td><td>null</td><td>null</td></tr><tr><td>min</td><td>1129</td><td>1</td><td>albers</td><td>2</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>American</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td><td>3</td><td>1</td><td>20</td><td>NA</td><td>null</td></tr><tr><td>25%</td><td>215336</td><td>24</td><td>null</td><td>8</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>30</td><td>215</td><td>7</td><td>20</td><td>null</td><td>null</td></tr><tr><td>50%</td><td>289733</td><td>52</td><td>null</td><td>17</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>37</td><td>852</td><td>16</td><td>21</td><td>null</td><td>null</td></tr><tr><td>75%</td><td>395109</td><td>817</td><td>null</td><td>31</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>43</td><td>885</td><td>29</td><td>22</td><td>null</td><td>null</td></tr><tr><td>max</td><td>472320</td><td>848</td><td>zonta</td><td>99</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>Venezuelan</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>48</td><td>1030</td><td>70</td><td>24</td><td>NA</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# %md
#
# Looks like I was right about positions >= 20 all being NA. But why are there
# NAs in positions 16-19 for some but not all entries? Looking at the tables
# and the plot optinons above, we can ascertain two things:
#
# 1. There are more missing values the lower the position (with 1 being the
# highest position).
# 2. It can't purely be due to any driver-based attributes, since the same
# drivers have missing and non-missing milliseconds values even at positions
# 16 and greater. It also can't be due to the time attribute, since all entries
# with missing time also have missing milliseconds (but I don't think that's
# what we're looking for).
#
# That leaves race, lap and position. Looking at them below.

# %%
df_milliseconds_na.groupby('raceId').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 419</div>

# %%
df_milliseconds_filled_pos_filter.groupby('raceId').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 432</div>

# %%
df_missing.groupby('raceId').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 437</div>

# %%
df_missing.groupby('lap').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: 78</div>

# %%
df_milliseconds_na.groupby('lap').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: 77</div>

# %%
df_milliseconds_race1_pos_16 = df_missing\
  .filter(F.col('position') >= 16)\
  .filter(F.col('raceId') == 1)
display(df_milliseconds_race1_pos_16)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>14422</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>9</td><td>17</td><td>NA</td><td>null</td></tr><tr><td>14503</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>3</td><td>17</td><td>1:31.697</td><td>91697</td></tr><tr><td>14554</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>1</td><td>17</td><td>2:37.754</td><td>157754</td></tr><tr><td>14571</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>4</td><td>17</td><td>1:31.867</td><td>91867</td></tr><tr><td>14585</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>8</td><td>17</td><td>1:31.801</td><td>91801</td></tr><tr><td>14602</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>10</td><td>17</td><td>1:33.063</td><td>93063</td></tr><tr><td>14762</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>7</td><td>17</td><td>1:31.659</td><td>91659</td></tr><tr><td>14800</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>2</td><td>17</td><td>1:37.640</td><td>97640</td></tr><tr><td>14883</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>5</td><td>17</td><td>1:32.234</td><td>92234</td></tr><tr><td>15011</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>14</td><td>17</td><td>1:31.408</td><td>91408</td></tr><tr><td>15105</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>24</td><td>16</td><td>2:15.301</td><td>135301</td></tr><tr><td>15181</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>15</td><td>17</td><td>1:31.232</td><td>91232</td></tr><tr><td>15208</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>NA</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td>6</td><td>17</td><td>1:32.036</td><td>92036</td></tr><tr><td>15219</td><td>2</td><td>heidfeld</td><td>null</td><td>HEI</td><td>Nick</td><td>Heidfeld</td><td>1977-05-10</td><td>German</td><td>http://en.wikipedia.org/wiki/Nick_Heidfeld</td><td>42</td><td>1</td><td ...

# %% [markdown]
# My suspicion was that the last 5 positions of each race were knocked off.
# This explains why 20-24 were always empty, with more missing values the closer
# a position is to 20.
#
# I decided to look more closely at a specific race - race 1. This quickly
# disproved my hypothesis. Race 1 contains positions up to 19, but one laptime
# for position 18 (Adrian Sutil), in lap 8, was recorded.
#
# This eliminates a strict raceId + position based removal, because the same
# race has missing and non-missing values for the same driver, having the same
# final position for the race.
#
# A lap based explanation also seems implausible. The dataset
# containing only missing milliseconds data has all but one of the laps
# represented. From the summary data, we can see that this is the maximum lap
# number, lap 78. This is probably absent because people in the final positions
# crash out and never get to that last lap, meaning the whole row is missing
# instead of just the millisecond data. Incompletions are very common in F1.
# So, the missingness pattern has little  to do with the lap number.
#
# The final possibility I can think of is lap + position, where earlier positions
# have less laptimes taken off, and later positions have more laptimes taken off.
# While this has already been established to be true from the bargraph of
# position and number of non-missing milliseconds data, I don't see a clear rule
# to decide which laps are missed out. Race 1, Position 17 has missing values
# for lap 9, 13, 19, among others, whereas position 18 is missing laps 1-7,
# 9-21, 23 and 24.
#
# It seems completely arbitrary to me. At this point, it seems like the pattern
# of missing milliseconds data is weighted probabilistically according to position
# from the range of 16-19. Milliseconds data is completely absent beyond 20, and
# all milliseconds data is available for positions above 15.
#
# Moving on.

# %% [markdown]
# ### Nationality

# %%
df_nationality_na = df_missing.filter(F.col('nationality') == 'NA')
display(df_nationality_na)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>12</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>37</td><td>28</td><td>2</td><td>1:37.673</td><td>97673</td></tr><tr><td>62</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>841</td><td>4</td><td>2</td><td>1:32.582</td><td>92582</td></tr><tr><td>67</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>841</td><td>9</td><td>2</td><td>1:32.612</td><td>92612</td></tr><tr><td>79</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>841</td><td>21</td><td>2</td><td>1:31.212</td><td>91212</td></tr><tr><td>98</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>841</td><td>40</td><td>2</td><td>1:31.200</td><td>91200</td></tr><tr><td>120</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>842</td><td>18</td><td>2</td><td>1:43.388</td><td>103388</td></tr><tr><td>125</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>842</td><td>23</td><td>2</td><td>1:43.009</td><td>103009</td></tr><tr><td>128</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>842</td><td>26</td><td>5</td><td>1:43.322</td><td>103322</td></tr><tr><td>141</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>842</td><td>39</td><td>5</td><td>1:43.305</td><td>103305</td></tr><tr><td>152</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>979</td><td>4</td><td>5</td><td>2:09.188</td><td>129188</td></tr><tr><td>180</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>22</td><td>6</td><td>2</td><td>1:27.742</td><td>87742</td></tr><tr><td>183</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>22</td><td>9</td><td>2</td><td>1:27.307</td><td>87307</td></tr><tr><td>216</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>872</td><td>32</td><td>1</td><td>1:28.962</td><td>88962</td></tr><tr><td>234</td><td>1</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>NA</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>872</td><td>50</td><td>1</td><td>1:28.729</td><td>88729</td></tr><tr>< ...

# %%
display(df_nationality_na.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>47112</td><td>47112</td><td>47112</td><td>22915</td><td>47112</td><td>47112</td><td>47112</td><td>47112</td><td>47112</td><td>47112</td><td>40914</td><td>47112</td><td>47112</td><td>47112</td><td>47112</td><td>42431</td></tr><tr><td>mean</td><td>236831.90064102566</td><td>229.8604177279674</td><td>null</td><td>25.375561859044293</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>36.9850417949846</td><td>478.89633214467653</td><td>29.8841059602649</td><td>9.670168959076245</td><td>null</td><td>94927.01703942871</td></tr><tr><td>stddev</td><td>136309.13495101867</td><td>345.22003963236295</td><td>null</td><td>25.059337728224083</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7.277806101583822</td><td>401.7174307637275</td><td>18.453123903650155</td><td>5.565508413514029</td><td>null</td><td>53836.48933054257</td></tr><tr><td>min</td><td>12</td><td>1</td><td>albers</td><td>2</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>NA</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td><td>1</td><td>1</td><td>1</td><td>19:16.450</td><td>67377</td></tr><tr><td>25%</td><td>118420</td><td>14</td><td>null</td><td>8</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>32</td><td>112</td><td>14</td><td>5</td><td>null</td><td>81868</td></tr><tr><td>50%</td><td>237628</td><td>30</td><td>null</td><td>19</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>38</td><td>227</td><td>29</td><td>9</td><td>null</td><td>90279</td></tr><tr><td>75%</td><td>354286</td><td>807</td><td>null</td><td>28</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>43</td><td>910</td><td>44</td><td>14</td><td>null</td><td>102057</td></tr><tr><td>max</td><td>472486</td><td>848</td><td>zonta</td><td>99</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>NA</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>48</td><td>1030</td><td>78</td><td>24</td><td>NA</td><td>3681464</td></tr></tbody></table></div>

# %%
# 47112 is the same number we saw in the groupby above, so we should be good
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(df_missing.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>_c0</th><th>driverId</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th></tr></thead><tbody><tr><td>count</td><td>472504</td><td>472504</td><td>472504</td><td>230938</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>411348</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>425253</td></tr><tr><td>mean</td><td>236252.5</td><td>229.7737775764861</td><td>null</td><td>25.328412820757087</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>36.98124702198625</td><td>480.07822156002914</td><td>29.871804259858116</td><td>9.651368030746829</td><td>null</td><td>94899.58912224017</td></tr><tr><td>stddev</td><td>136400.3001340784</td><td>345.3821632369074</td><td>null</td><td>24.985651553593236</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7.251128022983076</td><td>402.0313510566064</td><td>18.38969559962932</td><td>5.562433907092902</td><td>null</td><td>66244.43117416694</td></tr><tr><td>min</td><td>1</td><td>1</td><td>albers</td><td>2</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>American</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td><td>1</td><td>1</td><td>1</td><td>15:25.994</td><td>66957</td></tr><tr><td>25%</td><td>118129</td><td>14</td><td>null</td><td>8</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>32</td><td>112</td><td>14</td><td>5</td><td>null</td><td>81931</td></tr><tr><td>50%</td><td>236205</td><td>30</td><td>null</td><td>19</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>38</td><td>228</td><td>29</td><td>9</td><td>null</td><td>90364</td></tr><tr><td>75%</td><td>354341</td><td>807</td><td>null</td><td>28</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>43</td><td>911</td><td>44</td><td>14</td><td>null</td><td>102028</td></tr><tr><td>max</td><td>472504</td><td>848</td><td>zonta</td><td>99</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>Venezuelan</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>48</td><td>1030</td><td>78</td><td>24</td><td>NA</td><td>7507547</td></tr></tbody></table></div>

# %% [markdown]
# Again this cannot be driver based - we see here a lot of missing values for
# Lewis Hamilton, but above we saw some entries with Lewis Hamilton listed as
# British. Since the same driver has both missing and non-missing values, a pure
# driver-based criterion for missing data is ruled out.
#
# That leaves raceId, lap, position, and timing data. I am not optimistic
# here either, since the descriptives for these are almost identical to the
# whole df_missing dataset. This suggests that the df_nationality_na dataset
# is randomly sampled from the full df_missing dataset, and hence that the
# nationality missingness was randomly imposed.
#
# Still I think I should have a look.

# %%
df_missing.groupby('raceId').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: 437</div>

# %%
df_nationality_na.groupby('raceId').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[33]: 437</div>

# %%
df_missing.groupby('lap').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[34]: 78</div>

# %%
df_nationality_na.groupby('lap').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: 78</div>

# %%
df_missing.groupby('position').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: 24</div>

# %%
df_nationality_na.groupby('position').agg(F.max('position')).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: 24</div>

# %% [markdown]
# All races, positions, and laps are represented in our nationality-missing
# dataset. There is also entries where nationality is missing for both
# valid and missing millisecond data.
#
# These suggest that any "@ this position/lap/race, remove nationality"
# isn't what is happening.
#
# There could be a more complex hard and/or probabilistic rule "@ this
# position, remove nationality for this lap/race/driver/timing range with
# this probability". But that's going to be awfully difficult to see from data
# exploration or even visualisation, especially given, the high number of laps
# and races.
#
# I think it's reasonable to assume that the nationality missingness is randomly
# imposed, particularly given the lack of bias in the distributions of any other
# variable in the dataset.

# %% [markdown]
# ## 2. Plot the distributions of variables with missing values against the observed ones and explain how different missingness patterns are affecting the distributions.

# %% [markdown]
# ## Prep data
# 1. Get original data
# 2. Use the fill_dummy_values function to prepare the data for the plot
# 3. toPandas() - don't want to have to deal with matplotlib + pyspark

# %%
df_laptimes = spark.read.csv('/mnt/ne-gr5069/raw/lap_times.csv', header = True)
df_drivers = spark.read.csv('/mnt/ne-gr5069/raw/drivers.csv', header = True)

df_drivers_with_age = df_drivers\
  .withColumn("age", F.datediff(F.current_date(),F.col("dob"))/365.25)
df_drivers_with_age = df_drivers_with_age\
  .withColumn("age", df_drivers_with_age["age"].cast(IntegerType()))

df_original = df_laptimes.join(df_drivers_with_age, on = ['driverId'])
display(df_original.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>driverId</th><th>raceId</th><th>lap</th><th>position</th><th>time</th><th>milliseconds</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th></tr></thead><tbody><tr><td>count</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td></tr><tr><td>mean</td><td>229.7737775764861</td><td>480.07822156002914</td><td>29.871804259858116</td><td>9.651368030746829</td><td>null</td><td>95554.85977473206</td><td>null</td><td>25.328412820757087</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>39.119495284696</td></tr><tr><td>stddev</td><td>345.38216323690835</td><td>402.0313510566062</td><td>18.38969559962933</td><td>5.5624339070928865</td><td>null</td><td>71232.1852395675</td><td>null</td><td>24.985651553593197</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>8.728104640739067</td></tr><tr><td>min</td><td>1</td><td>1</td><td>1</td><td>1</td><td>10:32.179</td><td>100000</td><td>albers</td><td>10</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>American</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td></tr><tr><td>25%</td><td>14.0</td><td>112.0</td><td>14.0</td><td>5.0</td><td>null</td><td>82237.0</td><td>null</td><td>8.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>32</td></tr><tr><td>50%</td><td>30.0</td><td>228.0</td><td>29.0</td><td>9.0</td><td>null</td><td>90881.0</td><td>null</td><td>19.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>38</td></tr><tr><td>75%</td><td>807.0</td><td>911.0</td><td>44.0</td><td>14.0</td><td>null</td><td>102661.0</td><td>null</td><td>28.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>47</td></tr><tr><td>max</td><td>9</td><td>999</td><td>9</td><td>9</td><td>9:45.712</td><td>99999</td><td>zonta</td><td>\N</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>Venezuelan</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>62</td></tr></tbody></table></div>

# %%
df_full = df_missing.join(df_original.select(F.col('driverId'),
                                             F.col('raceId'),
                                             F.col('lap'),
                                             F.col('nationality').alias('og_nat'),
                                             F.col('milliseconds').alias('og_ms'),
                                             F.col('age').alias('og_age')
                                            ), on = ['driverId', 'raceId', 'lap']
                         )

df_full = df_full.withColumn("og_ms", df_full["og_ms"].cast(IntegerType()))
display(df_full)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>driverId</th><th>raceId</th><th>lap</th><th>_c0</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>position</th><th>time</th><th>milliseconds</th><th>og_nat</th><th>og_ms</th><th>og_age</th></tr></thead><tbody><tr><td>1</td><td>5</td><td>37</td><td>10561</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>9</td><td>1:24.159</td><td>84159</td><td>British</td><td>84159</td><td>35</td></tr><tr><td>1</td><td>9</td><td>7</td><td>13501</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>20</td><td>NA</td><td>null</td><td>British</td><td>103434</td><td>35</td></tr><tr><td>1</td><td>9</td><td>23</td><td>12453</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>19</td><td>NA</td><td>null</td><td>British</td><td>97195</td><td>35</td></tr><tr><td>1</td><td>10</td><td>23</td><td>6656</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>1</td><td>1:24.557</td><td>84557</td><td>British</td><td>84557</td><td>35</td></tr><tr><td>1</td><td>13</td><td>35</td><td>827</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>5</td><td>1:48.433</td><td>108433</td><td>British</td><td>108433</td><td>35</td></tr><tr><td>1</td><td>21</td><td>42</td><td>9082</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>3</td><td>1:22.313</td><td>82313</td><td>British</td><td>82313</td><td>35</td></tr><tr><td>1</td><td>25</td><td>49</td><td>11615</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>10</td><td>1:17.828</td><td>77828</td><td>British</td><td>77828</td><td>35</td></tr><tr><td>1</td><td>26</td><td>25</td><td>13634</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>1</td><td>1:34.946</td><td>94946</td><td>British</td><td>94946</td><td>35</td></tr><tr><td>1</td><td>27</td><td>56</td><td>6150</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>3</td><td>1:16.879</td><td>76879</td><td>British</td><td>76879</td><td>35</td></tr><tr><td>1</td><td>33</td><td>20</td><td>12380</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>15</td><td>1:21.772</td><td>81772</td><td>British</td><td>81772</td><td>35</td></tr><tr><td>1</td><td>33</td><td>44</td><td>2675</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>12</td><td>1:20.727</td><td>80727</td><td>British</td><td>80727</td><td>35</td></tr><tr><td>1</td><td>45</td><td>7</td><td>10602</td><td>hamilton</td><td>44</td><td>HAM</td><td>Lewis</td><td>Hamilton</td><td>1985-01-07</td><td>British</td><td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td><td>35</td><td>17</td> ...

# %%
display(df_full.summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>driverId</th><th>raceId</th><th>lap</th><th>_c0</th><th>driverRef</th><th>number</th><th>code</th><th>forename</th><th>surname</th><th>dob</th><th>nationality</th><th>url</th><th>age</th><th>position</th><th>time</th><th>milliseconds</th><th>og_nat</th><th>og_ms</th><th>og_age</th></tr></thead><tbody><tr><td>count</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>230938</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>472504</td><td>411348</td><td>472504</td><td>472504</td><td>425253</td><td>472504</td><td>472504</td><td>472504</td></tr><tr><td>mean</td><td>229.7737775764861</td><td>480.07822156002914</td><td>29.871804259858116</td><td>236252.5</td><td>null</td><td>25.328412820757087</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>36.98124702198625</td><td>9.651368030746829</td><td>null</td><td>94899.58912224017</td><td>null</td><td>95554.85977473206</td><td>39.119495284696</td></tr><tr><td>stddev</td><td>345.3821632369095</td><td>402.0313510566072</td><td>18.389695599629317</td><td>136400.30013407842</td><td>null</td><td>24.985651553593183</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>7.251128022983017</td><td>5.562433907092896</td><td>null</td><td>66244.4311741669</td><td>null</td><td>71232.18523956732</td><td>8.72810464073903</td></tr><tr><td>min</td><td>1</td><td>1</td><td>1</td><td>1</td><td>albers</td><td>2</td><td>ALB</td><td>Adrian</td><td>Albers</td><td>1958-02-18</td><td>American</td><td>http://en.wikipedia.org/wiki/Adrian_Sutil</td><td>20</td><td>1</td><td>15:25.994</td><td>66957</td><td>American</td><td>66957</td><td>20</td></tr><tr><td>25%</td><td>14</td><td>112</td><td>14</td><td>118538</td><td>null</td><td>8</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>32</td><td>5</td><td>null</td><td>81931</td><td>null</td><td>82244</td><td>32</td></tr><tr><td>50%</td><td>30</td><td>228</td><td>29</td><td>236242</td><td>null</td><td>19</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>38</td><td>9</td><td>null</td><td>90363</td><td>null</td><td>90900</td><td>38</td></tr><tr><td>75%</td><td>807</td><td>911</td><td>44</td><td>354514</td><td>null</td><td>28</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>43</td><td>14</td><td>null</td><td>102067</td><td>null</td><td>102676</td><td>47</td></tr><tr><td>max</td><td>848</td><td>1030</td><td>78</td><td>472504</td><td>zonta</td><td>99</td><td>\N</td><td>Zsolt</td><td>van der Garde</td><td>1999-11-13</td><td>Venezuelan</td><td>http://en.wikipedia.org/wiki/Zsolt_Baumgartner</td><td>48</td><td>24</td><td>NA</td><td>7507547</td><td>Venezuelan</td><td>7507547</td><td>62</td></tr></tbody></table></div>

# %%
df_full_pd = df_full.toPandas()
df_full_dummy_vals = fill_dummy_values(df_full_pd, 0.075)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1583455334968-0/PythonShell.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# </div>

# %% [markdown]
# ## Age

# %%
#Get missing values for coloring
null_age = df_full_pd['age'].isnull()

#Generate Scatter plot
fig_age, ax = plt.subplots()
df_full_dummy_vals.plot(x = 'age',
                        y = 'og_age',
                        kind = 'scatter',
                        alpha = 0.5,
                        c = null_age,
                        cmap = 'rainbow',
                        figsize=(12,8),
                        grid = True,
                        legend = True,
                        ax = ax)
ax.legend(['Not Missing'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: &lt;matplotlib.legend.Legend at 0x7f00e87e71d0&gt;</div>

# %%
fig_age_NA_compare = plt.figure(figsize = (12,10))
sns.distplot(df_full_pd['age'], hist = False, kde = True,
             color = 'red', 
             kde_kws={'linewidth': 2})
sns.distplot(df_full_pd['og_age'], hist = False, kde = True,
             color = 'blue', 
             kde_kws={'linewidth': 2})
display(fig_age_NA_compare)

# %%
display(fig_age)

# %% [markdown]
# As a result of the missingness pattern in the age data, the overall
# distribution of ages in df_missing is much younger. In the missing data,
# there was no data above age 50.
#
# There were some minor differences in how I calculated age from the
# df_missing dataset (I used the current day's timestamp, subtracting
# DOB). Nevertheless, for ages that were available, differences were
# minor (see scatterplot), suggesting this computational differences
# would not be sufficient to account for significantly larger ages of
# those whose ages were missing from df_missing.

# %% [markdown]
# ## Milliseconds

# %%
#Get missing values for coloring
null_ms = df_full_pd['milliseconds'].isnull()

#Generate Scatter plot
fig_ms, ax = plt.subplots()
df_full_dummy_vals.plot(x = 'milliseconds',
                        y = 'og_ms',
                        kind = 'scatter',
                        alpha = 0.5,
                        c = null_ms,
                        cmap = 'rainbow',
                        figsize=(12,8),
                        grid = True,
                        legend = True,
                        ax = ax)
ax.legend(['Not Missing'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: &lt;matplotlib.legend.Legend at 0x7f00e86b6240&gt;</div>

# %%
fig_ms_NA_compare = plt.figure(figsize = (12,10))
sns.distplot(df_full_pd['og_ms'], hist = False, kde = True,
             color = 'blue', 
             kde_kws={'linewidth': 2})
sns.distplot(df_full_pd['milliseconds'], hist = False, kde = True,
             color = 'red', 
             kde_kws={'linewidth': 2})
display(fig_ms_NA_compare)

# %%
display(fig_ms)

# %% [markdown]
# The overall distributions in laptimes seems very similar between the
# original observed data and the data contained in df_missing. In the
# density plot, the two curves overlap to the point where distinguishing
# them becomes difficult. The full data has slightly higher peaks, with
# the most prominent at the first and highest peak near 0. I don't think
# this is indicative of a skew in the df_missing laptimes data towards
# faster laps, despite how missingness in the laptime data was related to
# race position, as the higher blue peaks are true for all of the peaks,
# and the scatterplot of original against df_missing data appears to have
# a very similar distribution. I think it is more likely that the
# higher peaks reflect a greater frequency of data in the full dataset at
# all points in the distribution, since it also includes data that was
# missing in the df_missing dataset.
#
# The overall distribution of laptimes in df_missing thus does not seem
# affected by the pattern of missingness in the df_missing dataset for
# the milliseconds column.

# %% [markdown]
# ## Nationality

# %%
nat_count = pd.DataFrame(df_full_pd['nationality'].value_counts())
nat_og_count = pd.DataFrame(df_full_pd['og_nat'].value_counts())
nat_count_df = nat_count.join(nat_og_count)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(nat_count_df.plot(kind = 'bar'))

# %%
display(nat_count_df.plot.scatter(x = 'nationality',
                                  y = 'og_nat'))

# %% [markdown]
# The overall frequency distribution of nationality in the full data and
# df_missing seem very similar. This is also seen in the perfectly linear
# relationship between the two distributions in the scatterplot.
#
# Like with the laptimes data, the peaks
# for each nationality is higher than the df_missing data, but that is likely
# due to the inclusion of entries that were missing in the df_missing dataset.
#
# The similar shapes of the distributions suggests that the overall frequency
# distribution of nationalities in df_missing was not affected by the pattern of
# missingness in the df_missing dataset for the nationalities column. This also
# somewhat supports the notion that the pattern of missingness in this column
# was completely randomly imposed.

# %% [markdown]
# ## 3. Based on your findings, use at least two different imputation techniques to impute the variables for further analysis. Assess the effectiveness of imputation techniques both visually and analytically (e.g. using an appropriate accuracy metric that you defined).

# %% [markdown]
# ### KNN imputation

# %%
df_missing_for_impute = df_missing.toPandas()
df_missing_for_impute = df_missing_for_impute[['driverId',
                                               'age',
                                               'raceId',
                                               'nationality',
                                               'lap',
                                               'position',
                                               'milliseconds']]

df_missing_for_impute = df_missing_for_impute.replace('NA', np.nan)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Encode nationality as ordinal variable to run KNN imputer
encoder = OrdinalEncoder()
encoded_nat = encode(df_missing_for_impute['nationality'])
encoder.categories_
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Out[52]: [array([&#39;American&#39;, &#39;Argentine&#39;, &#39;Australian&#39;, &#39;Austrian&#39;, &#39;Belgian&#39;,
#         &#39;Brazilian&#39;, &#39;British&#39;, &#39;Canadian&#39;, &#39;Colombian&#39;, &#39;Czech&#39;, &#39;Danish&#39;,
#         &#39;Dutch&#39;, &#39;Finnish&#39;, &#39;French&#39;, &#39;German&#39;, &#39;Hungarian&#39;, &#39;Indian&#39;,
#         &#39;Indonesian&#39;, &#39;Irish&#39;, &#39;Italian&#39;, &#39;Japanese&#39;, &#39;Malaysian&#39;,
#         &#39;Mexican&#39;, &#39;Monegasque&#39;, &#39;New Zealander&#39;, &#39;Polish&#39;, &#39;Portuguese&#39;,
#         &#39;Russian&#39;, &#39;Spanish&#39;, &#39;Swedish&#39;, &#39;Swiss&#39;, &#39;Thai&#39;, &#39;Venezuelan&#39;],
#        dtype=object)]</div>

# %%
df_missing_for_impute['nationality'] = encoded_nat
df_missing_for_impute.head(15)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>driverId</th>
#       <th>age</th>
#       <th>raceId</th>
#       <th>nationality</th>
#       <th>lap</th>
#       <th>position</th>
#       <th>milliseconds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>17</td>
#       <td>2</td>
#       <td>97663.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>18</td>
#       <td>2</td>
#       <td>97579.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>19</td>
#       <td>1</td>
#       <td>97720.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>20</td>
#       <td>1</td>
#       <td>100973.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>21</td>
#       <td>3</td>
#       <td>120933.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>22</td>
#       <td>3</td>
#       <td>96701.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>23</td>
#       <td>2</td>
#       <td>97257.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>24</td>
#       <td>2</td>
#       <td>97907.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>25</td>
#       <td>2</td>
#       <td>98180.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>26</td>
#       <td>2</td>
#       <td>97822.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>27</td>
#       <td>2</td>
#       <td>97816.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>NaN</td>
#       <td>28</td>
#       <td>2</td>
#       <td>97673.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>29</td>
#       <td>2</td>
#       <td>97892.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>30</td>
#       <td>2</td>
#       <td>98006.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1</td>
#       <td>35.0</td>
#       <td>37</td>
#       <td>6</td>
#       <td>31</td>
#       <td>2</td>
#       <td>97787.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Run KNNImputer
# This takes very long to run, so I've run it and saved the output in S3. 
# Will continue the assignment by reading this in.

#knn_imputer = KNNImputer(n_neighbors=10)
#fill missing values by imputing
#array_missing_imputed = knn_imputer.fit_transform(df_missing_for_impute)
#df_missing_imputed = pd.DataFrame(array_missing_imputed)
#spark_df_missing_imputed = spark.createDataFrame(df_missing_imputed)
#spark_df_missing_imputed.coalesce(1).write.csv('/mnt/xql2001-gr5069/interim/assignment_2/spark_df_missing_imputed.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_missing_imputed = spark.read.csv('/mnt/xql2001-gr5069/interim/assignment_2/spark_df_missing_imputed.csv', header = False)
display(df_missing_imputed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th></tr></thead><tbody><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>17.0</td><td>2.0</td><td>97663.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>18.0</td><td>2.0</td><td>97579.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>19.0</td><td>1.0</td><td>97720.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>20.0</td><td>1.0</td><td>100973.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>21.0</td><td>3.0</td><td>120933.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>22.0</td><td>3.0</td><td>96701.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>23.0</td><td>2.0</td><td>97257.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>24.0</td><td>2.0</td><td>97907.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>25.0</td><td>2.0</td><td>98180.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>26.0</td><td>2.0</td><td>97822.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>27.0</td><td>2.0</td><td>97816.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>14.3</td><td>28.0</td><td>2.0</td><td>97673.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>29.0</td><td>2.0</td><td>97892.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>30.0</td><td>2.0</td><td>98006.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>31.0</td><td>2.0</td><td>97787.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>32.0</td><td>2.0</td><td>97838.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>33.0</td><td>2.0</td><td>98159.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>34.0</td><td>2.0</td><td>98254.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>35.0</td><td>2.0</td><td>97651.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>36.0</td><td>2.0</td><td>97848.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>37.0</td><td>2.0</td><td>97453.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>38.0</td><td>2.0</td><td>100742.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>39.0</td><td>5.0</td><td>121478.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>40.0</td><td>4.0</td><td>97951.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>41.0</td><td>4.0</td><td>98457.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>42.0</td><td>3.0</td><td>99019.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>43.0</td><td>2.0</td><td>99450.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>44.0</td><td>2.0</td><td>99018.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>45.0</td><td>2.0</td><td>98605.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>46.0</td><td>2.0</td><td>98557.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>47.0</td><td>2.0</td><td>98680.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>48.0</td><td>2.0</td><td>99005.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>49.0</td><td>2.0</td><td>98326.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>50.0</td><td>2.0</td><td>98805.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>51.0</td><td>2.0</td><td>98380.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>52.0</td><td>2.0</td><td>98136.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>53.0</td><td>2.0</td><td>98199.0</td></tr><tr><td>1.0</td><td>35.0</td><td>37.0</td><td>6.0</td><td>54.0</td><td>2.0</ ...

# %%
pd_missing_imputed = df_missing_imputed.toPandas()
pd_missing_imputed = pd_missing_imputed.rename(columns={"_c0": "driverId",
                                                        "_c1": "age",
                                                        "_c2": "raceId",
                                                        "_c3": "nationality",
                                                        "_c4": "lap",
                                                        "_c5": "position",
                                                        "_c6": "milliseconds"}
                                              )
pd_missing_imputed = pd_missing_imputed.astype('float64', copy=False)
pd_missing_imputed['nationality'] = np.round(pd_missing_imputed['nationality'])

nat_dict = {0: 'American',
            1: 'Argentine',
            2: 'Australian',
            3: 'Austrian',
            4: 'Belgian',
            5: 'Brazilian',
            6: 'British',
            7: 'Canadian',
            8: 'Colombian',
            9: 'Czech',
            10: 'Danish',
            11: 'Dutch',
            12: 'Finnish',
            13: 'French',
            14: 'German',
            15: 'Hungarian',
            16: 'Indian',
            17: 'Indonesian',
            18: 'Irish',
            19: 'Italian',
            20: 'Japanese',
            21: 'Malaysian',
            22: 'Mexican',
            23: 'Monegasque',
            24: 'New Zealander',
            25: 'Polish',
            26: 'Portuguese',
            27: 'Russian',
            28: 'Spanish',
            29: 'Swedish',
            30: 'Swiss',
            31: 'Thai',
            32: 'Venezuelan'
           }

pd_missing_imputed['nationality'] = pd_missing_imputed['nationality'].map(nat_dict)
pd_missing_imputed.head(15)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>driverId</th>
#       <th>age</th>
#       <th>raceId</th>
#       <th>nationality</th>
#       <th>lap</th>
#       <th>position</th>
#       <th>milliseconds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>17.0</td>
#       <td>2.0</td>
#       <td>97663.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>18.0</td>
#       <td>2.0</td>
#       <td>97579.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>19.0</td>
#       <td>1.0</td>
#       <td>97720.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>20.0</td>
#       <td>1.0</td>
#       <td>100973.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>21.0</td>
#       <td>3.0</td>
#       <td>120933.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>22.0</td>
#       <td>3.0</td>
#       <td>96701.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>23.0</td>
#       <td>2.0</td>
#       <td>97257.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>24.0</td>
#       <td>2.0</td>
#       <td>97907.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>25.0</td>
#       <td>2.0</td>
#       <td>98180.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>26.0</td>
#       <td>2.0</td>
#       <td>97822.0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>27.0</td>
#       <td>2.0</td>
#       <td>97816.0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>German</td>
#       <td>28.0</td>
#       <td>2.0</td>
#       <td>97673.0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>29.0</td>
#       <td>2.0</td>
#       <td>97892.0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>30.0</td>
#       <td>2.0</td>
#       <td>98006.0</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1.0</td>
#       <td>35.0</td>
#       <td>37.0</td>
#       <td>British</td>
#       <td>31.0</td>
#       <td>2.0</td>
#       <td>97787.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Age

# %%
fig_age_imp_compare = plt.figure(figsize = (12,10))
sns.distplot(pd_missing_imputed['age'], hist = False, kde = True,
             color = 'red', 
             kde_kws={'linewidth': 2})
sns.distplot(df_full_pd['og_age'], hist = False, kde = True,
             color = 'blue', 
             kde_kws={'linewidth': 2})
display(fig_age_imp_compare)

# %%
missing_age_index = df_full_pd['age'].isna()
predicted_age_list = pd_missing_imputed['age'][missing_age_index]
actual_age_list = df_full_pd['og_age'][missing_age_index]
rmse_age = RMSE(predicted_age_list, actual_age_list)
rmse_age
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[75]: 16.88799241245684</div>

# %% [markdown]
# The KNN imputer was largely unsuccessful at imputing the missing values for
# age. The distribution of the data filled with the imputed values largely
# resembles the distribution of ages in df_missing before imputation.
# The distribution of ages remains younger than the actual data. One redeeming
# factor of the KNN model is a higher peak at the high 40s in the imputed data
# compared to the df_missing data, suggesting that the model successfully
# inferred that the drivers with missing age data were older. However, without
# exposure to ages beyond 50, it was unable to impute the ages of these drivers
# to be as old as they actually are.
#
# Quantitatively, the limited effectiveness of the KNN imputer can be seen in
# the RMSE value of 16.9, which is high for a distribution with a range of only
# about 40.

# %% [markdown]
# #### Milliseconds

# %%
fig_ms_imp_compare = plt.figure(figsize = (12,10))
sns.distplot(df_full_pd['og_ms'], hist = False, kde = True,
             color = 'blue', 
             kde_kws={'linewidth': 2})
sns.distplot(pd_missing_imputed['milliseconds'], hist = False, kde = True,
             color = 'red', 
             kde_kws={'linewidth': 2})
display(fig_ms_imp_compare)

# %%
missing_ms_index = df_full_pd['milliseconds'].isna()
predicted_ms_list = pd_missing_imputed['milliseconds'][missing_age_index]
actual_ms_list = df_full_pd['og_ms'][missing_age_index]
rmse_ms = RMSE(predicted_ms_list, actual_ms_list)
rmse_ms
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[157]: 72906.63581083345</div>

# %% [markdown]
# At first glance, the KNN imputer seemed largely successful in imputing
# missing laptime data. This is seen in the RMSE of 72906, which is small for a
#  variable with a range in the millions. In the plot, we see that the
# imputation created a skew in laptimes towards faster laps, imputing more
# missing values as having lower values than was actually observed. This was
# likely due to the disproportionate volume of fast laps in the dataset. This
# effect does not seem to be too severe given the small RMSE value and the fact
# that the imputed and actual data density plots are still very similar in
# shape.
#
# Nevertheless, by creating the skew, the imputer created a laptime distribution
# that is less similar to the distribution of the full data than the df_missing
# laptime distribution. Rather than having a skew towards faster laps, however
# minor, the df_missing laptime distribution was very similar to that of the full
# data.
#
# By shifting the distribution of missing data to be less similar to the full
# data than the actual distribution, the KNN imputer proved to be less effective
# than just removing missing values, at least for the case of representing the
# distribution of F1 laptimes.

# %% [markdown]
# #### Nationality

# %%
fig_nat_imp_compare = plt.figure(figsize = (12,10))
sns.countplot(y = 'nationality',
              data=pd_missing_imputed,
              color = 'red',
              alpha = 0.5)
sns.countplot(y = 'og_nat',
              data=df_full_pd,
              color = 'blue',
              alpha = 0.5)
display(fig_nat_imp_compare)

# %%
missing_nat_index = df_full_pd['nationality'] == 'NA'
predicted_nat_list = pd_missing_imputed['nationality'][missing_nat_index]
actual_nat_list = df_full_pd['og_nat'][missing_nat_index]
confusion_matrix_nat = confusion_matrix(actual_nat_list, predicted_nat_list)
nat_accuracy = np.diagonal(confusion_matrix_nat).sum()/missing_nat_index.sum()
nat_accuracy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[174]: 0.08450076413652573</div>

# %%
fig_nat_cm = plt.figure(figsize = (10,10))
sns.heatmap(confusion_matrix_nat)
display(fig_nat_cm)

# %% [markdown]
# The KNN imputer did a devastatingly poor job at imputing the missing
# nationalities data. This can be seen from:
#
# 1. The dismal accuracy of 0.08 (though to be fair, chance is about 3%, so
# the model is better than chance, but beating chance is very far from what
# we need for missing values imputation).
# 2. The density plot, where no nationality was at all well predicted, except
# maybe for British and Germans.
# 2. The heatmap of the confusion matrix (should have high counts on the
# diagonals, which is only somewhat true).
#
#
# The imputer predicted less members of the frequent entries, like British
# and German, and more members of the infrequent nationalities such as Irish and
# Danish. However, the model also tended to miss out other infrequent
# nationalities like Finnish and Brazillian.
#
# This was likely because with the KNN imputer, we had to code nationality as
# ordinal data, when it is in fact nominal. OneHotEncoding is more appropriate
# for nominal data, but since it creates features based on membership to a
# category, missing data would not appear to be missing under OneHotEncoding,
# they would just appear as not a member of any class, leaving nothing to
# impute. The fact that driverId and raceId were also actually nominal features
# but were included as continuous features were also likely contributors to the
# issue.
#
# *Honestly I didn't anticipate that this would be too much of a problem, and*
# *have now run out of time to retrain new models for imputation, so I'm going*
# *with what I have. In my defense, properly encoding driver and race Id probably*
# *would have created a better model but also would've meant creating about 2000*
# *new features. That would have made model training take a lot longer than I*
# *have time for.*

# %% [markdown]
# ### Mean/Modal imputation

# %%
df_mean_mode_impute = df_full_pd.copy(deep = True)
df_mean_mode_impute['age'].fillna(df_mean_mode_impute['age'].mean(),
                                  inplace = True)
df_mean_mode_impute['milliseconds'].fillna(df_mean_mode_impute['milliseconds'].mean(),
                                           inplace = True)

mode_nationality = "German"
df_mean_mode_impute['nationality'] = df_mean_mode_impute['nationality'].str.replace('NA', mode_nationality)
df_mean_mode_impute.head(20)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>driverId</th>
#       <th>raceId</th>
#       <th>lap</th>
#       <th>_c0</th>
#       <th>driverRef</th>
#       <th>number</th>
#       <th>code</th>
#       <th>forename</th>
#       <th>surname</th>
#       <th>dob</th>
#       <th>nationality</th>
#       <th>url</th>
#       <th>age</th>
#       <th>position</th>
#       <th>time</th>
#       <th>milliseconds</th>
#       <th>og_nat</th>
#       <th>og_ms</th>
#       <th>og_age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>5</td>
#       <td>37</td>
#       <td>10561</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>9</td>
#       <td>1:24.159</td>
#       <td>84159.000000</td>
#       <td>British</td>
#       <td>84159</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>9</td>
#       <td>7</td>
#       <td>13501</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>20</td>
#       <td>NA</td>
#       <td>94899.589122</td>
#       <td>British</td>
#       <td>103434</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>9</td>
#       <td>23</td>
#       <td>12453</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>19</td>
#       <td>NA</td>
#       <td>94899.589122</td>
#       <td>British</td>
#       <td>97195</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>10</td>
#       <td>23</td>
#       <td>6656</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>1</td>
#       <td>1:24.557</td>
#       <td>84557.000000</td>
#       <td>British</td>
#       <td>84557</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>13</td>
#       <td>35</td>
#       <td>827</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>5</td>
#       <td>1:48.433</td>
#       <td>108433.000000</td>
#       <td>British</td>
#       <td>108433</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1</td>
#       <td>21</td>
#       <td>42</td>
#       <td>9082</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>3</td>
#       <td>1:22.313</td>
#       <td>82313.000000</td>
#       <td>British</td>
#       <td>82313</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1</td>
#       <td>25</td>
#       <td>49</td>
#       <td>11615</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>10</td>
#       <td>1:17.828</td>
#       <td>77828.000000</td>
#       <td>British</td>
#       <td>77828</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1</td>
#       <td>26</td>
#       <td>25</td>
#       <td>13634</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>1</td>
#       <td>1:34.946</td>
#       <td>94946.000000</td>
#       <td>British</td>
#       <td>94946</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1</td>
#       <td>27</td>
#       <td>56</td>
#       <td>6150</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>3</td>
#       <td>1:16.879</td>
#       <td>76879.000000</td>
#       <td>British</td>
#       <td>76879</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1</td>
#       <td>33</td>
#       <td>20</td>
#       <td>12380</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>15</td>
#       <td>1:21.772</td>
#       <td>81772.000000</td>
#       <td>British</td>
#       <td>81772</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1</td>
#       <td>33</td>
#       <td>44</td>
#       <td>2675</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>12</td>
#       <td>1:20.727</td>
#       <td>80727.000000</td>
#       <td>British</td>
#       <td>80727</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>1</td>
#       <td>45</td>
#       <td>7</td>
#       <td>10602</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>17</td>
#       <td>NA</td>
#       <td>94899.589122</td>
#       <td>British</td>
#       <td>161715</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1</td>
#       <td>46</td>
#       <td>37</td>
#       <td>7136</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>1</td>
#       <td>1:21.974</td>
#       <td>81974.000000</td>
#       <td>British</td>
#       <td>81974</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>1</td>
#       <td>46</td>
#       <td>60</td>
#       <td>597</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>1</td>
#       <td>1:21.265</td>
#       <td>81265.000000</td>
#       <td>British</td>
#       <td>81265</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>1</td>
#       <td>344</td>
#       <td>39</td>
#       <td>3894</td>
#       <td>hamilton</td>
#       <td>44.0</td>
#       <td>HAM</td>
#       <td>Lewis</td>
#       <td>Hamilton</td>
#       <td>1985-01-07</td>
#       <td>British</td>
#       <td>http://en.wikipedia.org/wiki/Lewis_Hamilton</td>
#       <td>35.0</td>
#       <td>2</td>
#       <td>1:18.810</td>
#       <td>78810.000000</td>
#       <td>British</td>
#       <td>78810</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>1</td>
#       <td>349</td>
#       <td>27</t

# %% [markdown]
# #### Age

# %%
fig_age_mean_imp_compare = plt.figure(figsize = (12,10))
sns.distplot(df_mean_mode_impute['age'], hist = False, kde = True,
             color = 'red', 
             kde_kws={'linewidth': 2})
sns.distplot(df_full_pd['og_age'], hist = False, kde = True,
             color = 'blue', 
             kde_kws={'linewidth': 2})
display(fig_age_mean_imp_compare)

# %%
predicted_age_list_mean_imp = df_mean_mode_impute['age'][missing_age_index]
rmse_age_mean_imp = RMSE(predicted_age_list_mean_imp, actual_age_list)
rmse_age_mean_imp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[155]: 16.29005335432163</div>

# %% [markdown]
# The mean imputation was largely unsuccessful at imputing the missing values for
# age. Like the KNN imputer, the distribution of the data filled with the imputed
# values largely resembles the distribution of ages in df_missing before
# imputation, save for the tall peak at the mean age of about 37. Visually, the
# mean imputation seems to have performed more poorly than KNN imputation given
# the lower resemblance to the original distribution, due to the tall peak.
# This is despite a slightly lower RMSE value for mean imputation  at 16.3
# instead of 16.9. Nevertheless, 16.2 remains high for a distribution with a
# range of only about 40.
#
# Like the KNN imputed distribution, the distribution of ages remains younger
# than the actual data. Using only the mean, the mean imputation could not
# rightly infer that the drivers with missing ages were older, unlike the KNN
# imputation.
#
# Overall, the mean imputation was unsuccessful, and seemed to perform worse
# than KNN imputation for filling in the missing age date.

# %% [markdown]
# #### Milliseconds

# %%
fig_ms_mean_imp_compare = plt.figure(figsize = (12,10))
sns.distplot(df_full_pd['og_ms'], hist = False, kde = True,
             color = 'blue', 
             kde_kws={'linewidth': 2})
sns.distplot(df_mean_mode_impute['milliseconds'], hist = False, kde = True,
             color = 'red', 
             kde_kws={'linewidth': 2})
display(fig_ms_mean_imp_compare)

# %%
predicted_ms_list_mean_imp = df_mean_mode_impute['milliseconds'][missing_age_index]
rmse_ms_mean_imp = RMSE(predicted_ms_list_mean_imp, actual_ms_list)
rmse_ms_mean_imp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[186]: 8941.524095164037</div>

# %% [markdown]
# Overall, the mean imputation seems successful at imputing missing values for
# laptimes.
#
# Quantitatively, the RMSE value of 8941 is very small compared to the range
# of over 7 million. Visually, the mean imputed distribution lacks the skew
# at around 500k milliseconds that was present in the KNN imputed distribution,
# closely adhering to the original distribution.
#
# However, there are two notable deviations.
#
# First, the prominent blue peak at about 100000ms. This is more pronounced in
# this plot than in the plot from question 2 comparing the df_missing laptime
# data to the full data, despite identical settings. This is very odd given
# that mean imputation should have increased, not decreased the number of values
# at 100000ms, which is about the mean value that was imputed (about 94k).
# After spending quite some time checking if my code was correct, I think it
# probably was, and what we see is probably related to the smoothing of the plot
# rather than changes in the distribution.
#
# Second, blue peaks popping out over the red line at all peaks across the
# distributionshows that the mean imputation was imperfect at restoring the data
# to its original state, with less red values across the range being similar to
# the plot from question 2 comparing the df_missing laptime data to the full
# data.

# %% [markdown]
# #### Nationality

# %%
fig_nat_mode_imp_compare = plt.figure(figsize = (12,10))
sns.countplot(y = 'nationality',
              data=df_mean_mode_impute,
              color = 'red',
              alpha = 0.5)
sns.countplot(y = 'og_nat',
              data=df_full_pd,
              color = 'blue',
              alpha = 0.5)
display(fig_nat_mode_imp_compare)

# %%
predicted_nat_mode_imp_list = df_mean_mode_impute['nationality'][missing_nat_index]
confusion_matrix_mode_imp_nat = confusion_matrix(actual_nat_list, predicted_nat_mode_imp_list)
nat_mode_imp_accuracy = (np.diagonal(confusion_matrix_mode_imp_nat).sum())/missing_nat_index.sum()
nat_mode_imp_accuracy
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[179]: 0.17723722193920868</div>

# %%
fig_nat_mode_imp_cm = plt.figure(figsize = (10,10))
sns.heatmap(confusion_matrix_mode_imp_nat)
display(fig_nat_mode_imp_cm)

# %% [markdown]
# The modal imputer did a poor job at imputing the missing nationalities data.
# This can be seen from:
#
# 1. The accuracy of 0.17, which is much better than chance at 0.03125, but far
# from what we need as an imputer. That being said, modal imputation outperformed
# the KNN imputer.
# 2. The density plot, which predictably overestimated the modal nationality
# (German) while leaving every other nationality lacking in representation
# in the data.
# 2. The heatmap of the confusion matrix (the colourful strip is German), and
# the diagonal is pretty much black when it should be white.

# %%
#Unmount S3 buckets
#dbutils.fs.unmount("/mnt/%s" % MOUNT_NAME_RAW)
#dbutils.fs.unmount("/mnt/%s" % MOUNT_NAME_PROC)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
